# %% [markdown]
# ### Author: Yikang Li

# %% [markdown]
# As a Data Scientist, I want to explore my data set with visualizations and common statistical characteristics pertaining to time series in particular so that I can understand the nature and shape of the the data and get an idea of what algorithms will perform best.
#
# To Do:
# Check each feature, extract characteristics.
# Check Correlation among the features and their extracted characteristics.
# Visualize time series data and explore trends and characteristics using Plotly and Cufflinks.
# Transform the data in the spectral domain using fast fourier transform and perform the same EDA to get more information.
# Study the seasonal decomposition of the time series of each column and check the trend and seasonality and other such characteristics.
#
# Also, perform the same plotting for minute and 15 minute data.

# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import cufflinks as cf
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
from  plotly.offline import plot

from datetime import datetime
import pandas_datareader.data as web

# %%
#load the data
house1 = pd.read_csv("./processed/house_01.csv")
house2 = pd.read_csv("./processed/house_02.csv")
house3 = pd.read_csv("./processed/house_03.csv")
house4 = pd.read_csv("./processed/house_04.csv")
house5 = pd.read_csv("./processed/house_05.csv")
house6 = pd.read_csv("./processed/house_06.csv")

# %% [markdown]
# ### House 1:

# %%
house1.head()
# Out:
#    Unnamed: 0                 date  occupancy   Fridge    Dryer  \
# 0           0  2012-06-01 00:00:00        NaN  49.2516  830.508
# 1           1  2012-06-01 00:00:01        NaN  49.2516  834.774
# 2           2  2012-06-01 00:00:02        NaN  49.2516  834.774
# 3           3  2012-06-01 00:00:03        NaN  51.3899  832.641
# 4           4  2012-06-01 00:00:04        NaN  49.2516  832.641
#
#    Coffee machine  Kettle  Washing machine  Freezer
# 0             NaN     0.0          4.39739  2.23178
# 1             NaN     0.0          4.39739  2.23178
# 2             NaN     0.0          4.39739  2.23178
# 3             NaN     0.0          4.39739  2.23178
# 4             NaN     0.0          6.53380  2.23178

# %% [markdown]
# The values are missing in columns "occupancy" and "Coffee machine".

# %% [markdown]
# #### Statistical Characteristics:

# %%
house1.describe()
# Out:
#          Unnamed: 0     occupancy        Fridge         Dryer  Coffee machine  \
# count  2.039040e+07  7.344000e+06  1.987200e+07  1.987200e+07    9.676800e+06
# mean   1.019520e+07  7.859397e-01  2.070984e+01  2.246613e+01    4.421196e+00
# std    5.886202e+06  4.101689e-01  2.497417e+01  1.298046e+02    7.318194e+01
# min    0.000000e+00  0.000000e+00 -1.000000e+00 -1.000000e+00   -1.000000e+00
# 25%    5.097600e+06  1.000000e+00  2.205780e+00  0.000000e+00    0.000000e+00
# 50%    1.019520e+07  1.000000e+00  4.344320e+00  0.000000e+00    0.000000e+00
# 75%    1.529280e+07  1.000000e+00  4.925160e+01  0.000000e+00    0.000000e+00
# max    2.039040e+07  1.000000e+00  1.012680e+03  1.018200e+03    1.290880e+03
#
#              Kettle  Washing machine       Freezer
# count  1.745280e+07     1.987200e+07  1.987200e+07
# mean   4.402760e+00     2.336620e+01  1.822220e+01
# std    9.016391e+01     1.870091e+02  1.556339e+01
# min   -1.000000e+00    -1.000000e+00 -1.000000e+00
# 25%    0.000000e+00     0.000000e+00  2.231780e+00
# 50%    0.000000e+00     0.000000e+00  3.027450e+01
# 75%    0.000000e+00     2.260970e+00  3.243160e+01
# max    1.902460e+03     2.427990e+03  1.057640e+02

# %%
house1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20390400 entries, 0 to 20390399
# Data columns (total 9 columns):
# Unnamed: 0         int64
# date               object
# occupancy          float64
# Fridge             float64
# Dryer              float64
# Coffee machine     float64
# Kettle             float64
# Washing machine    float64
# Freezer            float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 1.4+ GB

# %% [markdown]
# #### Correlation:

# %%
pd.DataFrame.corr(house1)
# Out:
#                  Unnamed: 0  occupancy    Fridge     Dryer  Coffee machine  \
# Unnamed: 0         1.000000  -0.124171 -0.035811  0.018758       -0.005077
# occupancy         -0.124171   1.000000  0.027438  0.065237        0.034402
# Fridge            -0.035811   0.027438  1.000000  0.011183        0.006161
# Dryer              0.018758   0.065237  0.011183  1.000000       -0.001826
# Coffee machine    -0.005077   0.034402  0.006161 -0.001826        1.000000
# Kettle             0.015791   0.026767  0.002722  0.002089        0.034834
# Washing machine    0.014661   0.039345  0.010244  0.048201        0.003753
# Freezer           -0.070602   0.004867  0.018268  0.001266        0.001518
#
#                    Kettle  Washing machine   Freezer
# Unnamed: 0       0.015791         0.014661 -0.070602
# occupancy        0.026767         0.039345  0.004867
# Fridge           0.002722         0.010244  0.018268
# Dryer            0.002089         0.048201  0.001266
# Coffee machine   0.034834         0.003753  0.001518
# Kettle           1.000000         0.004929 -0.005632
# Washing machine  0.004929         1.000000  0.006294
# Freezer         -0.005632         0.006294  1.000000

# %% [markdown]
# #### Visualize time series data:

# %%
plotly.tools.set_credentials_file('liyikang', 'gFn5H8Cy4VbGagtM2IUR')

# %%
house1_dt = house1[['date','Fridge', 'Dryer', 'Kettle', 'Washing machine', 'Freezer']].iloc[:10000, :]
house1_dt.iplot(kind = "scatter", x = 'date')
# Out:
# The draw time for this plot will be slow for clients without much RAM.
# /Users/glance/anaconda3/lib/python3.6/site-packages/plotly/api/v1/clientresp.py:40: UserWarning:
#
# Estimated Draw Time Slow
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~liyikang/48.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# #### minute and 15 minute data:

# %%
group_mins = house1.groupby(np.arange(len(house1))//60)
house1_by_mins = pd.concat((group_mins['date'].first(), group_mins[[c for c in house1.columns if c != 'date']].sum()), axis=1)
house1_by_mins.head()
# Out:
#                   date  Unnamed: 0  occupancy     Fridge        Dryer  \
# 0  2012-06-01 00:00:00        1770        0.0  2976.4790  50107.77500
# 1  2012-06-01 00:01:00        5370        0.0  2963.6492  49883.80200
# 2  2012-06-01 00:02:00        8970        0.0  2946.5424  49873.13800
# 3  2012-06-01 00:03:00       12570        0.0  2935.8504  24947.11340
# 4  2012-06-01 00:04:00       16170        0.0  2918.7432   4482.35334
#
#    Coffee machine  Kettle  Washing machine     Freezer
# 0             0.0     0.0        291.61673   102.66188
# 1             0.0     0.0        295.88955   706.65375
# 2             0.0     0.0        291.61672  1937.26730
# 3             0.0     0.0        300.16237  1986.87900
# 4             0.0     0.0        302.29878  1995.50700

# %%
house1_by_mins[['date','Fridge', 'Dryer', 'Kettle', 'Washing machine', 'Freezer']].iplot(kind = "scatter", x = 'date')
# Out:
# /Users/glance/anaconda3/lib/python3.6/site-packages/plotly/plotly/plotly.py:230: UserWarning:
#
# Woah there! Look at all those points! Due to browser limitations, the Plotly SVG drawing functions have a hard time graphing more than 500k data points for line charts, or 40k points for other types of charts. Here are some suggestions:
# (1) Use the `plotly.graph_objs.Scattergl` trace object to generate a WebGl graph.
# (2) Trying using the image API to return an image instead of a graph URL
# (3) Use matplotlib
# (4) See if you can create your visualization with fewer data points
#
# If the visualization you're using aggregates points (e.g., box plot, histogram, etc.) you can disregard this warning.
# The draw time for this plot will be slow for all clients.
# /Users/glance/anaconda3/lib/python3.6/site-packages/plotly/api/v1/clientresp.py:40: UserWarning:
#
# Estimated Draw Time Too Long
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~liyikang/50.embed" height="525px" width="100%"></iframe>

# %%
group_15mins = house1.groupby(np.arange(len(house1))//900)
house1_by_15mins = pd.concat((group_15mins['date'].first(), group_15mins[[c for c in house1.columns if c != 'date']].sum()), axis=1)
house1_by_15mins.head()
# Out:
#                   date  Unnamed: 0  occupancy       Fridge         Dryer  \
# 0  2012-06-01 00:00:00      404550        0.0  43507.43140  195942.03986
# 1  2012-06-01 00:15:00     1214550        0.0  12909.26128   24376.89486
# 2  2012-06-01 00:30:00     2024550        0.0   1166.85762    7796.92002
# 3  2012-06-01 00:45:00     2834550        0.0   1158.03450     453.45420
# 4  2012-06-01 01:00:00     3644550        0.0   1135.97670     527.93460
#
#    Coffee machine  Kettle  Washing machine      Freezer
# 0             0.0     0.0       4459.70734  26138.31223
# 1             0.0     0.0       4436.20682  15496.66314
# 2             0.0     0.0       4466.11657   8083.31259
# 3             0.0     0.0       4425.52477  28938.21290
# 4             0.0     0.0       4434.07041   6333.14080

# %%
house1_by_15mins[['date','Fridge', 'Dryer', 'Kettle', 'Washing machine', 'Freezer']].iplot(kind = "scatter", x = 'date')
# Out:
# The draw time for this plot will be slow for all clients.
# /Users/glance/anaconda3/lib/python3.6/site-packages/plotly/api/v1/clientresp.py:40: UserWarning:
#
# Estimated Draw Time Too Long
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~liyikang/54.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ### House 2:

# %%
house2.head()
# Out:
#    Unnamed: 0                 date  occupancy   Tablet  Dishwasher  \
# 0           0  2012-06-01 00:00:00        1.0  2.21504         0.0
# 1           1  2012-06-01 00:00:01        1.0  4.32930         0.0
# 2           2  2012-06-01 00:00:02        1.0  2.21504         0.0
# 3           3  2012-06-01 00:00:03        1.0  2.21504         0.0
# 4           4  2012-06-01 00:00:04        1.0  2.21504         0.0
#
#    Air exhaust   Fridge  Entertainment  Freezer  Kettle  Lamp  Laptops  Stove  \
# 0          0.0  2.21458        0.00000  53.6510     0.0   0.0      0.0    NaN
# 1          0.0  2.21458        2.17127  55.7929     0.0   0.0      0.0    NaN
# 2          0.0  0.00000        0.00000  53.6510     0.0   0.0      0.0    NaN
# 3          0.0  0.00000        0.00000  53.6510     0.0   0.0      0.0    NaN
# 4          0.0  0.00000        0.00000  55.7929     0.0   0.0      0.0    NaN
#
#     Stereo
# 0  0.00000
# 1  2.17127
# 2  0.00000
# 3  0.00000
# 4  0.00000

# %% [markdown]
# #### Statistical Characteristics:

# %%
house2.describe()
# Out:
#          Unnamed: 0     occupancy        Tablet    Dishwasher   Air exhaust  \
# count  2.108160e+07  1.088640e+07  2.064960e+07  2.064960e+07  2.064960e+07
# mean   1.054080e+07  7.349464e-01  1.202025e+00  1.584929e+01  5.644951e-01
# std    6.085734e+06  4.413617e-01  1.397134e+00  1.801734e+02  7.394131e+00
# min    0.000000e+00  0.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00
# 25%    5.270400e+06  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    1.054080e+07  1.000000e+00  2.215040e+00  0.000000e+00  0.000000e+00
# 75%    1.581120e+07  1.000000e+00  2.215040e+00  0.000000e+00  0.000000e+00
# max    2.108160e+07  1.000000e+00  1.067200e+01  2.335920e+03  1.857060e+02
#
#              Fridge  Entertainment       Freezer        Kettle          Lamp  \
# count  2.064960e+07   2.030400e+07  2.064960e+07  2.064960e+07  2.064960e+07
# mean   2.438221e+01   5.348632e+01  2.710266e+01  4.761080e+00  1.494485e+01
# std    4.086490e+01   8.732343e+01  3.627581e+01  9.446724e+01  4.846570e+01
# min   -1.000000e+00  -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00
# 25%    0.000000e+00   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    6.817280e+01   5.511710e+01  5.365100e+01  0.000000e+00  0.000000e+00
# max    1.037750e+03   3.938480e+02  9.676080e+02  1.910490e+03  3.171390e+02
#
#             Laptops         Stove        Stereo
# count  2.064960e+07  2.419200e+06  2.064960e+07
# mean   6.049097e+00  1.338440e+01  1.641233e+01
# std    1.682079e+01  1.694802e+02  2.531551e+01
# min   -1.000000e+00  0.000000e+00 -1.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00  4.757200e+01
# max    1.613280e+03  6.224000e+03  7.883570e+02

# %%
house2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21081600 entries, 0 to 21081599
# Data columns (total 14 columns):
# Unnamed: 0       int64
# date             object
# occupancy        float64
# Tablet           float64
# Dishwasher       float64
# Air exhaust      float64
# Fridge           float64
# Entertainment    float64
# Freezer          float64
# Kettle           float64
# Lamp             float64
# Laptops          float64
# Stove            float64
# Stereo           float64
# dtypes: float64(12), int64(1), object(1)
# memory usage: 2.2+ GB

# %% [markdown]
# #### Correlation:

# %%
pd.DataFrame.corr(house2)
# Out:
#                Unnamed: 0  occupancy    Tablet  Dishwasher  Air exhaust  \
# Unnamed: 0       1.000000  -0.035678 -0.042770   -0.000696     0.012986
# occupancy       -0.035678   1.000000 -0.016264    0.030555     0.051676
# Tablet          -0.042770  -0.016264  1.000000    0.026378     0.011852
# Dishwasher      -0.000696   0.030555  0.026378    1.000000     0.002779
# Air exhaust      0.012986   0.051676  0.011852    0.002779     1.000000
# Fridge          -0.027235   0.026999  0.032669    0.004039     0.015754
# Entertainment    0.051407   0.363817  0.029561    0.060516     0.066469
# Freezer         -0.067576  -0.002114  0.033417    0.001657     0.006188
# Kettle          -0.009343   0.034912  0.003525   -0.002181     0.045596
# Lamp             0.210775   0.165345  0.001212    0.023605     0.087837
# Laptops         -0.033360   0.217732  0.023116    0.047590     0.031006
# Stove           -0.021155   0.047757 -0.001898    0.064955     0.328872
# Stereo           0.031542   0.383578  0.050481    0.064952     0.085361
#
#                  Fridge  Entertainment   Freezer    Kettle      Lamp  \
# Unnamed: 0    -0.027235       0.051407 -0.067576 -0.009343  0.210775
# occupancy      0.026999       0.363817 -0.002114  0.034912  0.165345
# Tablet         0.032669       0.029561  0.033417  0.003525  0.001212
# Dishwasher     0.004039       0.060516  0.001657 -0.002181  0.023605
# Air exhaust    0.015754       0.066469  0.006188  0.045596  0.087837
# Fridge         1.000000       0.029078  0.022544  0.001513  0.003777
# Entertainment  0.029078       1.000000  0.016083  0.031613  0.447210
# Freezer        0.022544       0.016083  1.000000 -0.000304 -0.005653
# Kettle         0.001513       0.031613 -0.000304  1.000000  0.013271
# Lamp           0.003777       0.447210 -0.005653  0.013271  1.000000
# Laptops        0.010800       0.350369  0.014593  0.026646  0.234802
# Stove          0.006518       0.045343  0.009558  0.009525 -0.012703
# Stereo         0.034642       0.839844  0.036533  0.031175  0.378230
#
#                 Laptops     Stove    Stereo
# Unnamed: 0    -0.033360 -0.021155  0.031542
# occupancy      0.217732  0.047757  0.383578
# Tablet         0.023116 -0.001898  0.050481
# Dishwasher     0.047590  0.064955  0.064952
# Air exhaust    0.031006  0.328872  0.085361
# Fridge         0.010800  0.006518  0.034642
# Entertainment  0.350369  0.045343  0.839844
# Freezer        0.014593  0.009558  0.036533
# Kettle         0.026646  0.009525  0.031175
# Lamp           0.234802 -0.012703  0.378230
# Laptops        1.000000  0.095065  0.341828
# Stove          0.095065  1.000000  0.047801
# Stereo         0.341828  0.047801  1.000000

# %% [markdown]
# #### Visualize time series data:

# %%
house2_dt = house2[['date', 'occupancy', 'Tablet', 'Dishwasher',
       'Air exhaust', 'Fridge', 'Entertainment', 'Freezer', 'Kettle', 'Lamp',
       'Laptops', 'Stove', 'Stereo']].iloc[:10000, :]
house2_dt.iplot(kind = "scatter", x = 'date')
# Out:
# The draw time for this plot will be slow for all clients.
# /Users/glance/anaconda3/lib/python3.6/site-packages/plotly/api/v1/clientresp.py:40: UserWarning:
#
# Estimated Draw Time Too Long
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~liyikang/56.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# #### minute and 15 minute data:

# %%
group_mins = house2.groupby(np.arange(len(house2))//60)
house2_by_mins = pd.concat((group_mins['date'].first(), group_mins[[c for c in house2.columns if c != 'date']].sum()), axis=1)
house2_by_mins.head()
# Out:
#                   date  Unnamed: 0  occupancy     Tablet  Dishwasher  \
# 0  2012-06-01 00:00:00        1770       60.0  147.70222         0.0
# 1  2012-06-01 00:01:00        5370       60.0  154.04500         0.0
# 2  2012-06-01 00:02:00        8970       60.0  154.04500         0.0
# 3  2012-06-01 00:03:00       12570       60.0  145.58796         0.0
# 4  2012-06-01 00:04:00       16170       60.0  149.81648         0.0
#
#    Air exhaust    Fridge  Entertainment    Freezer  Kettle     Lamp  Laptops  \
# 0      0.00000  50.93534       21.71270  3240.4790     0.0  2.23556      0.0
# 1      2.23367  22.14580       26.05524  3204.0667     0.0  0.00000      0.0
# 2      0.00000  26.57496       26.05524  3169.7963     0.0  2.23556      0.0
# 3      0.00000  19.93122       30.39778  3141.9516     0.0  0.00000      0.0
# 4      0.00000  24.36038       21.71270  3150.5192     0.0  2.23556      0.0
#
#    Stove    Stereo
# 0    0.0  21.71270
# 1    0.0  26.05524
# 2    0.0  26.05524
# 3    0.0  30.39778
# 4    0.0  21.71270

# %%
house2_by_mins[['date', 'occupancy', 'Tablet', 'Dishwasher',
       'Air exhaust', 'Fridge', 'Entertainment', 'Freezer', 'Kettle', 'Lamp',
       'Laptops', 'Stove', 'Stereo']].iloc[0:10000, :].iplot(kind = "scatter", x = 'date')
# Out:
# The draw time for this plot will be slow for all clients.
# /Users/glance/anaconda3/lib/python3.6/site-packages/plotly/api/v1/clientresp.py:40: UserWarning:
#
# Estimated Draw Time Too Long
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~liyikang/58.embed" height="525px" width="100%"></iframe>

# %%
group_15mins = house2.groupby(np.arange(len(house2))//900)
house2_by_15mins = pd.concat((group_15mins['date'].first(), group_15mins[[c for c in house2.columns if c != 'date']].sum()), axis=1)
house2_by_15mins.head()
# Out:
#                   date  Unnamed: 0  occupancy      Tablet  Dishwasher  \
# 0  2012-06-01 00:00:00      404550      900.0  2156.13246         0.0
# 1  2012-06-01 00:15:00     1214550      900.0  1795.28886         0.0
# 2  2012-06-01 00:30:00     2024550      900.0   959.11232         0.0
# 3  2012-06-01 00:45:00     2834550      900.0   945.82208         0.0
# 4  2012-06-01 01:00:00     3644550      900.0  1007.84320         0.0
#
#    Air exhaust       Fridge  Entertainment      Freezer  Kettle      Lamp  \
# 0      6.70101    372.04944      384.31479  33969.36568     0.0  17.88448
# 1      6.70101  58471.07208      410.37003  21125.77860     0.0  15.64892
# 2      4.46734   4215.81695      395.17114  28818.56302     0.0  17.88448
# 3      2.23367    367.62028      423.39765  23092.35510     0.0  17.88448
# 4      4.46734  36376.85084      382.14352  34197.44060     0.0  24.59116
#
#    Laptops  Stove     Stereo
# 0      0.0    0.0  384.31479
# 1      0.0    0.0  410.37003
# 2      0.0    0.0  395.17114
# 3      0.0    0.0  423.39765
# 4      0.0    0.0  382.14352

# %%
house2_by_15mins[['date', 'occupancy', 'Tablet', 'Dishwasher',
       'Air exhaust', 'Fridge', 'Entertainment', 'Freezer', 'Kettle', 'Lamp',
       'Laptops', 'Stove', 'Stereo']].iplot(kind = "scatter", x = 'date')
# Out:
# The draw time for this plot will be slow for all clients.
# /Users/glance/anaconda3/lib/python3.6/site-packages/plotly/api/v1/clientresp.py:40: UserWarning:
#
# Estimated Draw Time Too Long
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~liyikang/60.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ### House 3:

# %%
house3.head()
# Out:
#    Unnamed: 0                 date  occupancy  Tablet  Freezer  \
# 0           0  2012-10-23 00:00:00        NaN    -1.0     -1.0
# 1           1  2012-10-23 00:00:01        NaN    -1.0     -1.0
# 2           2  2012-10-23 00:00:02        NaN    -1.0     -1.0
# 3           3  2012-10-23 00:00:03        NaN    -1.0     -1.0
# 4           4  2012-10-23 00:00:04        NaN    -1.0     -1.0
#
#    Coffee machine  Fridge  Kettle  Entertainment
# 0            -1.0    -1.0     NaN            NaN
# 1            -1.0    -1.0     NaN            NaN
# 2            -1.0    -1.0     NaN            NaN
# 3            -1.0    -1.0     NaN            NaN
# 4            -1.0    -1.0     NaN            NaN

# %% [markdown]
# #### Statistical Characteristics:

# %%
house3.describe()
# Out:
#          Unnamed: 0     occupancy        Tablet       Freezer  Coffee machine  \
# count  8.640000e+06  1.814400e+06  8.294400e+06  8.294400e+06    5.184000e+06
# mean   4.320000e+06  7.438040e-01  1.280892e+00  5.770378e+00    2.899241e-01
# std    2.494153e+06  4.365315e-01  1.605000e+00  9.244474e+00    2.159075e+01
# min    0.000000e+00  0.000000e+00 -1.000000e+00 -1.000000e+00   -1.000000e+00
# 25%    2.160000e+06  0.000000e+00  0.000000e+00  0.000000e+00   -1.000000e+00
# 50%    4.320000e+06  1.000000e+00  0.000000e+00  2.225500e+00    0.000000e+00
# 75%    6.479999e+06  1.000000e+00  2.238570e+00  2.225500e+00    0.000000e+00
# max    8.639999e+06  1.000000e+00  1.071860e+01  7.439030e+01    1.295990e+03
#
#              Fridge        Kettle  Entertainment
# count  3.542400e+06  3.110400e+06   3.888000e+06
# mean   9.513641e+00  1.220957e+01   3.222176e+00
# std    2.689626e+01  1.587499e+02   1.457987e+01
# min   -1.000000e+00 -1.000000e+00  -1.000000e+00
# 25%   -1.000000e+00 -1.000000e+00  -1.000000e+00
# 50%    0.000000e+00  0.000000e+00   0.000000e+00
# 75%    0.000000e+00  0.000000e+00   0.000000e+00
# max    1.211630e+03  2.144880e+03   6.911880e+01

# %%
house3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8640000 entries, 0 to 8639999
# Data columns (total 9 columns):
# Unnamed: 0        int64
# date              object
# occupancy         float64
# Tablet            float64
# Freezer           float64
# Coffee machine    float64
# Fridge            float64
# Kettle            float64
# Entertainment     float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 593.3+ MB

# %% [markdown]
# #### Correlation:

# %%
pd.DataFrame.corr(house3)
# Out:
#                 Unnamed: 0  occupancy    Tablet   Freezer  Coffee machine  \
# Unnamed: 0        1.000000   0.246438  0.071583  0.028032       -0.009354
# occupancy         0.246438   1.000000 -0.098691  0.011559        0.025263
# Tablet            0.071583  -0.098691  1.000000  0.008209        0.001777
# Freezer           0.028032   0.011559  0.008209  1.000000        0.002975
# Coffee machine   -0.009354   0.025263  0.001777  0.002975        1.000000
# Fridge            0.013647   0.092494 -0.030414 -0.007825        0.002145
# Kettle           -0.019516  -0.038727 -0.011618  0.000474       -0.001492
# Entertainment     0.000505   0.117429  0.041807  0.006144        0.008450
#
#                   Fridge    Kettle  Entertainment
# Unnamed: 0      0.013647 -0.019516       0.000505
# occupancy       0.092494 -0.038727       0.117429
# Tablet         -0.030414 -0.011618       0.041807
# Freezer        -0.007825  0.000474       0.006144
# Coffee machine  0.002145 -0.001492       0.008450
# Fridge          1.000000  0.023615       0.017771
# Kettle          0.023615  1.000000       0.140681
# Entertainment   0.017771  0.140681       1.000000

# %% [markdown]
# #### Visualize time series data:

# %%
house3_dt = house3[['date', 'occupancy', 'Tablet', 'Freezer',
       'Coffee machine', 'Fridge', 'Kettle', 'Entertainment']].iloc[:10000, :]
house3_dt.iplot(kind = "scatter", x = 'date')
# Out:
# The draw time for this plot will be slow for all clients.
# /Users/glance/anaconda3/lib/python3.6/site-packages/plotly/api/v1/clientresp.py:40: UserWarning:
#
# Estimated Draw Time Too Long
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~liyikang/94.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# #### minute and 15 minute data:

# %%
group_mins = house3.groupby(np.arange(len(house3))//60)
house3_by_mins = pd.concat((group_mins['date'].first(), group_mins[[c for c in house3.columns if c != 'date']].sum()), axis=1)
house3_by_mins.head()
# Out:
#                   date  Unnamed: 0  occupancy  Tablet  Freezer  \
# 0  2012-10-23 00:00:00        1770        0.0   -60.0    -60.0
# 1  2012-10-23 00:01:00        5370        0.0   -60.0    -60.0
# 2  2012-10-23 00:02:00        8970        0.0   -60.0    -60.0
# 3  2012-10-23 00:03:00       12570        0.0   -60.0    -60.0
# 4  2012-10-23 00:04:00       16170        0.0   -60.0    -60.0
#
#    Coffee machine  Fridge  Kettle  Entertainment
# 0           -60.0   -60.0     0.0            0.0
# 1           -60.0   -60.0     0.0            0.0
# 2           -60.0   -60.0     0.0            0.0
# 3           -60.0   -60.0     0.0            0.0
# 4           -60.0   -60.0     0.0            0.0

# %%
house3_by_mins[['date', 'occupancy', 'Tablet', 'Freezer',
       'Coffee machine', 'Fridge', 'Kettle', 'Entertainment']].iplot(kind = "scatter", x = 'date')
# Out:
# /Users/glance/anaconda3/lib/python3.6/site-packages/plotly/plotly/plotly.py:230: UserWarning:
#
# Woah there! Look at all those points! Due to browser limitations, the Plotly SVG drawing functions have a hard time graphing more than 500k data points for line charts, or 40k points for other types of charts. Here are some suggestions:
# (1) Use the `plotly.graph_objs.Scattergl` trace object to generate a WebGl graph.
# (2) Trying using the image API to return an image instead of a graph URL
# (3) Use matplotlib
# (4) See if you can create your visualization with fewer data points
#
# If the visualization you're using aggregates points (e.g., box plot, histogram, etc.) you can disregard this warning.
# The draw time for this plot will be slow for all clients.
# /Users/glance/anaconda3/lib/python3.6/site-packages/plotly/api/v1/clientresp.py:40: UserWarning:
#
# Estimated Draw Time Too Long
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~liyikang/64.embed" height="525px" width="100%"></iframe>

# %%
group_15mins = house3.groupby(np.arange(len(house3))//900)
house3_by_15mins = pd.concat((group_15mins['date'].first(), group_15mins[[c for c in house3.columns if c != 'date']].sum()), axis=1)
house3_by_15mins.head()
# Out:
#                   date  Unnamed: 0  occupancy  Tablet  Freezer  \
# 0  2012-10-23 00:00:00      404550        0.0  -900.0   -900.0
# 1  2012-10-23 00:15:00     1214550        0.0  -900.0   -900.0
# 2  2012-10-23 00:30:00     2024550        0.0  -900.0   -900.0
# 3  2012-10-23 00:45:00     2834550        0.0  -900.0   -900.0
# 4  2012-10-23 01:00:00     3644550        0.0  -900.0   -900.0
#
#    Coffee machine  Fridge  Kettle  Entertainment
# 0          -900.0  -900.0     0.0            0.0
# 1          -900.0  -900.0     0.0            0.0
# 2          -900.0  -900.0     0.0            0.0
# 3          -900.0  -900.0     0.0            0.0
# 4          -900.0  -900.0     0.0            0.0

# %%
house3_by_15mins[['date', 'occupancy', 'Tablet', 'Freezer',
       'Coffee machine', 'Fridge', 'Kettle', 'Entertainment']].iplot(kind = "scatter", x = 'date')
# Out:
# The draw time for this plot will be slow for all clients.
# /Users/glance/anaconda3/lib/python3.6/site-packages/plotly/api/v1/clientresp.py:40: UserWarning:
#
# Estimated Draw Time Too Long
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~liyikang/66.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ### House 4:

# %%
house4.head()
# Out:
#    Unnamed: 0                 date  occupancy   Fridge  Kitchen appliances  \
# 0           0  2012-06-27 00:00:00        NaN  102.429             2.16516
# 1           1  2012-06-27 00:00:01        NaN  100.296             2.16516
# 2           2  2012-06-27 00:00:02        NaN  102.429             0.00000
# 3           3  2012-06-27 00:00:03        NaN  102.429             0.00000
# 4           4  2012-06-27 00:00:04        NaN  100.296             2.16516
#
#       Lamp  Stereo and laptop  Freezer   Tablet  Entertainment  Microwave
# 0  2.23978            15.0524  172.720  0.00000        10.7178    4.34694
# 1  2.23978            15.0524  170.589  0.00000        10.7178    2.23214
# 2  0.00000            15.0524  172.720  0.00000        10.7178    4.34694
# 3  0.00000            15.0524  172.720  2.22889        10.7178    4.34694
# 4  2.23978            15.0524  172.720  0.00000        10.7178    2.23214

# %% [markdown]
# #### Statistical Characteristics:

# %%
house4.describe()
# Out:
#          Unnamed: 0     occupancy        Fridge  Kitchen appliances  \
# count  1.814400e+07  7.430400e+06  1.667520e+07        1.667520e+07
# mean   9.072000e+06  9.335496e-01  2.703878e+01        9.410700e+00
# std    5.237722e+06  2.490678e-01  4.481938e+01        9.932784e+01
# min    0.000000e+00  0.000000e+00 -1.000000e+00       -1.000000e+00
# 25%    4.536000e+06  1.000000e+00  0.000000e+00        0.000000e+00
# 50%    9.072000e+06  1.000000e+00  0.000000e+00        0.000000e+00
# 75%    1.360800e+07  1.000000e+00  8.749980e+01        0.000000e+00
# max    1.814400e+07  1.000000e+00  1.174220e+03        2.331240e+03
#
#                Lamp  Stereo and laptop       Freezer        Tablet  \
# count  1.468800e+07       1.460160e+07  1.658880e+07  1.624320e+07
# mean   1.056615e+01       1.219372e+01  1.681490e+02  1.218688e+00
# std    2.793486e+01       1.428696e+01  1.063362e+02  4.544799e+00
# min   -1.000000e+00      -1.000000e+00 -1.000000e+00 -1.000000e+00
# 25%    0.000000e+00       0.000000e+00  9.386580e+01  0.000000e+00
# 50%    0.000000e+00       1.291450e+01  1.769820e+02  0.000000e+00
# 75%    2.239780e+00       1.505240e+01  2.600850e+02  2.228890e+00
# max    8.675200e+02       1.497260e+02  3.168810e+03  1.564990e+03
#
#        Entertainment     Microwave
# count   1.598400e+07  1.667520e+07
# mean    3.143746e+01  1.582864e+01
# std     4.181098e+01  1.311163e+02
# min    -1.000000e+00 -1.000000e+00
# 25%     1.071780e+01  2.232140e+00
# 50%     1.071780e+01  4.346940e+00
# 75%     4.257530e+01  4.346940e+00
# max     2.230670e+02  1.594670e+03

# %%
house4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18144000 entries, 0 to 18143999
# Data columns (total 11 columns):
# Unnamed: 0            int64
# date                  object
# occupancy             float64
# Fridge                float64
# Kitchen appliances    float64
# Lamp                  float64
# Stereo and laptop     float64
# Freezer               float64
# Tablet                float64
# Entertainment         float64
# Microwave             float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 1.5+ GB

# %% [markdown]
# #### Correlation:

# %%
pd.DataFrame.corr(house4)
# Out:
#                     Unnamed: 0  occupancy    Fridge  Kitchen appliances  \
# Unnamed: 0            1.000000   0.048192 -0.064277            0.015337
# occupancy             0.048192   1.000000  0.000025            0.024750
# Fridge               -0.064277   0.000025  1.000000            0.014399
# Kitchen appliances    0.015337   0.024750  0.014399            1.000000
# Lamp                  0.333668  -0.003765 -0.003508            0.018169
# Stereo and laptop    -0.335850   0.054727  0.051860            0.007180
# Freezer              -0.396736  -0.030660  0.056912            0.002179
# Tablet                0.059188  -0.034001  0.002854           -0.001926
# Entertainment         0.021430   0.121855  0.021206            0.009854
# Microwave             0.013133   0.026881  0.017328            0.090353
#
#                         Lamp  Stereo and laptop   Freezer    Tablet  \
# Unnamed: 0          0.333668          -0.335850 -0.396736  0.059188
# occupancy          -0.003765           0.054727 -0.030660 -0.034001
# Fridge             -0.003508           0.051860  0.056912  0.002854
# Kitchen appliances  0.018169           0.007180  0.002179 -0.001926
# Lamp                1.000000          -0.146481  0.048068  0.032655
# Stereo and laptop  -0.146481           1.000000  0.075864  0.009398
# Freezer             0.048068           0.075864  1.000000 -0.023911
# Tablet              0.032655           0.009398 -0.023911  1.000000
# Entertainment       0.037990           0.050456  0.079761  0.003521
# Microwave           0.018050           0.011214  0.006758  0.002853
#
#                     Entertainment  Microwave
# Unnamed: 0               0.021430   0.013133
# occupancy                0.121855   0.026881
# Fridge                   0.021206   0.017328
# Kitchen appliances       0.009854   0.090353
# Lamp                     0.037990   0.018050
# Stereo and laptop        0.050456   0.011214
# Freezer                  0.079761   0.006758
# Tablet                   0.003521   0.002853
# Entertainment            1.000000   0.025523
# Microwave                0.025523   1.000000

# %% [markdown]
# #### Visualize time series data:

# %%
house4_dt = house4[['date', 'occupancy', 'Fridge', 'Kitchen appliances',
       'Lamp', 'Stereo and laptop', 'Freezer', 'Tablet', 'Entertainment',
       'Microwave']].iloc[:10000, :]
house4_dt.iplot(kind = "scatter", x = 'date')
# Out:
# The draw time for this plot will be slow for all clients.
# /Users/glance/anaconda3/lib/python3.6/site-packages/plotly/api/v1/clientresp.py:40: UserWarning:
#
# Estimated Draw Time Too Long
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~liyikang/68.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# #### minute and 15 minute data:

# %%
group_mins = house4.groupby(np.arange(len(house4))//60)
house4_by_mins = pd.concat((group_mins['date'].first(), group_mins[[c for c in house4.columns if c != 'date']].sum()), axis=1)
house4_by_mins.head()
# Out:
#                   date  Unnamed: 0  occupancy     Fridge  Kitchen appliances  \
# 0  2012-06-27 00:00:00        1770        0.0  6090.2820            21.65160
# 1  2012-06-27 00:01:00        5370        0.0  6182.0010            54.12900
# 2  2012-06-27 00:02:00        8970        0.0  6135.0750            17.32128
# 3  2012-06-27 00:03:00       12570        0.0  6049.7560            41.13804
# 4  2012-06-27 00:04:00       16170        0.0  5977.2425            45.46836
#
#        Lamp  Stereo and laptop    Freezer    Tablet  Entertainment  Microwave
# 0  47.03538           886.0408  10318.449  57.95114      643.06800   229.0944
# 1  26.87736           853.9723  10307.794  78.01115      643.06800   197.3724
# 2  58.23428           845.4207  10318.449  64.63781      643.06802   182.5688
# 3  38.07626           862.5239  10260.912  69.09559      640.94412   222.7500
# 4  20.15802           881.7650  10243.864  35.66224      643.06800   226.9796

# %%
house4_by_mins[['date', 'occupancy', 'Fridge', 'Kitchen appliances',
       'Lamp', 'Stereo and laptop', 'Freezer', 'Tablet', 'Entertainment',
       'Microwave']].iloc[0:10000, :].iplot(kind = "scatter", x = 'date')
# Out:
# The draw time for this plot will be slow for all clients.
# /Users/glance/anaconda3/lib/python3.6/site-packages/plotly/api/v1/clientresp.py:40: UserWarning:
#
# Estimated Draw Time Too Long
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~liyikang/70.embed" height="525px" width="100%"></iframe>

# %%
group_15mins = house4.groupby(np.arange(len(house4))//900)
house4_by_15mins = pd.concat((group_15mins['date'].first(), group_15mins[[c for c in house4.columns if c != 'date']].sum()), axis=1)
house4_by_15mins.head()
# Out:
#                   date  Unnamed: 0  occupancy       Fridge  \
# 0  2012-06-27 00:00:00      404550        0.0  87041.93120
# 1  2012-06-27 00:15:00     1214550        0.0   5615.41787
# 2  2012-06-27 00:30:00     2024550        0.0     85.15533
# 3  2012-06-27 00:45:00     2834550        0.0     39.30246
# 4  2012-06-27 01:00:00     3644550        0.0  86007.65210
#
#    Kitchen appliances       Lamp  Stereo and laptop      Freezer     Tablet  \
# 0           480.66552  598.02126         13057.5809  153738.9380  833.60486
# 1           452.51844  602.50082         13004.1334  227019.6110  793.48484
# 2           474.17004  604.74060         13029.7882  203782.1050  521.56026
# 3           441.69264  562.18478         13012.6850  120148.5577  976.25382
# 4           474.17004  582.34280         13066.1325  158572.0460  846.97820
#
#    Entertainment  Microwave
# 0     9624.78126  3263.0024
# 1     9609.91412  3165.7216
# 2     9648.14398  3193.2140
# 3     9633.27676  3250.3136
# 4     9648.14400  3218.5916

# %%
house4_by_15mins[['date', 'occupancy', 'Fridge', 'Kitchen appliances',
       'Lamp', 'Stereo and laptop', 'Freezer', 'Tablet', 'Entertainment',
       'Microwave']].iplot(kind = "scatter", x = 'date')
# Out:
# The draw time for this plot will be slow for all clients.
# /Users/glance/anaconda3/lib/python3.6/site-packages/plotly/api/v1/clientresp.py:40: UserWarning:
#
# Estimated Draw Time Too Long
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~liyikang/72.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ### House 5:

# %%
house5.head()
# Out:
#    Unnamed: 0                 date  occupancy   Tablet  Coffee machine  \
# 0           0  2012-06-27 00:00:00        NaN  2.20778         4.48706
# 1           1  2012-06-27 00:00:01        NaN  2.20778         2.34770
# 2           2  2012-06-27 00:00:02        NaN  4.33249         4.48706
# 3           3  2012-06-27 00:00:03        NaN  4.33249         4.48706
# 4           4  2012-06-27 00:00:04        NaN  2.20778         2.34770
#
#    Fountain  Microwave   Fridge  Entertainment  Kettle
# 0   8.72041    4.44332  4.44546        6.56679     NaN
# 1   8.72041    4.44332  4.44546        8.69303     NaN
# 2   8.72041    6.57853  4.44546        8.69303     NaN
# 3   8.72041    4.44332  4.44546        6.56679     NaN
# 4   8.72041    4.44332  4.44546        8.69303     NaN

# %% [markdown]
# #### Statistical Characteristics:

# %%
house5.describe()
# Out:
#          Unnamed: 0     occupancy        Tablet  Coffee machine      Fountain  \
# count  1.883520e+07  6.393600e+06  1.874880e+07    1.874880e+07  6.134400e+06
# mean   9.417600e+06  9.008222e-01  4.598005e+00    5.523087e+00  1.193648e+01
# std    5.437254e+06  2.989006e-01  1.267522e+00    8.333408e+01  9.892267e+00
# min    0.000000e+00  0.000000e+00 -1.000000e+00   -1.000000e+00 -1.000000e+00
# 25%    4.708800e+06  1.000000e+00  4.332490e+00    0.000000e+00  8.720410e+00
# 50%    9.417600e+06  1.000000e+00  4.332490e+00    0.000000e+00  8.720410e+00
# 75%    1.412640e+07  1.000000e+00  4.332490e+00    0.000000e+00  8.720410e+00
# max    1.883520e+07  1.000000e+00  1.495590e+01    1.581540e+03  4.509910e+01
#
#           Microwave        Fridge  Entertainment        Kettle
# count  1.874880e+07  1.874880e+07   1.650240e+07  2.160000e+06
# mean   8.713093e+00  4.532431e+01   2.466514e+01  2.405304e-01
# std    8.431363e+01  5.822051e+01   5.580181e+01  2.190341e+01
# min   -1.000000e+00 -1.000000e+00  -1.000000e+00 -1.000000e+00
# 25%    4.443320e+00  4.445460e+00   2.314290e+00  0.000000e+00
# 50%    4.443320e+00  4.445460e+00   6.566790e+00  0.000000e+00
# 75%    6.578530e+00  1.128000e+02   8.693030e+00  0.000000e+00
# max    2.680550e+03  1.341410e+03   2.744300e+02  2.253180e+03

# %%
house5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18835200 entries, 0 to 18835199
# Data columns (total 10 columns):
# Unnamed: 0        int64
# date              object
# occupancy         float64
# Tablet            float64
# Coffee machine    float64
# Fountain          float64
# Microwave         float64
# Fridge            float64
# Entertainment     float64
# Kettle            float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.4+ GB

# %% [markdown]
# #### Correlation:

# %%
pd.DataFrame.corr(house5)
# Out:
#                 Unnamed: 0  occupancy    Tablet  Coffee machine  Fountain  \
# Unnamed: 0        1.000000  -0.095775 -0.034843        0.000702  0.017279
# occupancy        -0.095775   1.000000 -0.048231        0.018819  0.081846
# Tablet           -0.034843  -0.048231  1.000000        0.005634  0.031790
# Coffee machine    0.000702   0.018819  0.005634        1.000000 -0.017290
# Fountain          0.017279   0.081846  0.031790       -0.017290  1.000000
# Microwave        -0.015699   0.014140  0.012375        0.003413 -0.016810
# Fridge           -0.050267   0.010938  0.066179        0.007602  0.008741
# Entertainment     0.065159   0.076323  0.049081       -0.014424  0.116845
# Kettle           -0.006182        NaN  0.007990        0.000201       NaN
#
#                 Microwave    Fridge  Entertainment    Kettle
# Unnamed: 0      -0.015699 -0.050267       0.065159 -0.006182
# occupancy        0.014140  0.010938       0.076323       NaN
# Tablet           0.012375  0.066179       0.049081  0.007990
# Coffee machine   0.003413  0.007602      -0.014424  0.000201
# Fountain        -0.016810  0.008741       0.116845       NaN
# Microwave        1.000000  0.006285      -0.009260 -0.000520
# Fridge           0.006285  1.000000       0.009198 -0.003141
# Entertainment   -0.009260  0.009198       1.000000 -0.004216
# Kettle          -0.000520 -0.003141      -0.004216  1.000000

# %% [markdown]
# #### Visualize time series data:

# %%
house5_dt = house5[['date', 'occupancy', 'Tablet', 'Coffee machine',
       'Fountain', 'Microwave', 'Fridge', 'Entertainment', 'Kettle']].iloc[:10000, :]
house5_dt.iplot(kind = "scatter", x = 'date')
# Out:
# The draw time for this plot will be slow for all clients.
# /Users/glance/anaconda3/lib/python3.6/site-packages/plotly/api/v1/clientresp.py:40: UserWarning:
#
# Estimated Draw Time Too Long
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~liyikang/90.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# #### minute and 15 minute data:

# %%
group_mins = house5.groupby(np.arange(len(house5))//60)
house5_by_mins = pd.concat((group_mins['date'].first(), group_mins[[c for c in house5.columns if c != 'date']].sum()), axis=1)
house5_by_mins.head()
# Out:
#                   date  Unnamed: 0  occupancy     Tablet  Coffee machine  \
# 0  2012-06-27 00:00:00        1770        0.0  194.08339       245.69064
# 1  2012-06-27 00:01:00        5370        0.0  189.83397       239.27256
# 2  2012-06-27 00:02:00        8970        0.0  211.08107       249.96936
# 3  2012-06-27 00:03:00       12570        0.0  200.45752       239.27256
# 4  2012-06-27 00:04:00       16170        0.0  206.83165       239.27256
#
#    Fountain  Microwave     Fridge  Entertainment  Kettle
# 0  510.3846  319.97945  273.10203      464.17332     0.0
# 1  503.9646  322.11466  270.97722      472.67828     0.0
# 2  506.1046  309.30340  270.97722      470.55204     0.0
# 3  503.9646  319.97945  275.22684      457.79460     0.0
# 4  499.6846  319.97945  273.10203      455.66836     0.0

# %%
house5_by_mins[['date', 'occupancy', 'Tablet', 'Coffee machine',
       'Fountain', 'Microwave', 'Fridge', 'Entertainment', 'Kettle']].iloc[0:10000, :].iplot(kind = "scatter", x = 'date')
# Out:
# The draw time for this plot will be slow for all clients.
# /Users/glance/anaconda3/lib/python3.6/site-packages/plotly/api/v1/clientresp.py:40: UserWarning:
#
# Estimated Draw Time Too Long
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~liyikang/80.embed" height="525px" width="100%"></iframe>

# %%
group_15mins = house5.groupby(np.arange(len(house5))//900)
house5_by_15mins = pd.concat((group_15mins['date'].first(), group_15mins[[c for c in house5.columns if c != 'date']].sum()), axis=1)
house5_by_15mins.head()
# Out:
#                   date  Unnamed: 0  occupancy      Tablet  Coffee machine  \
# 0  2012-06-27 00:00:00      404550        0.0  2996.23925      3621.17880
# 1  2012-06-27 00:15:00     1214550        0.0  2957.99447      3621.17880
# 2  2012-06-27 00:30:00     2024550        0.0  2943.12150      3621.17880
# 3  2012-06-27 00:45:00     2834550        0.0  2943.12150      3606.20328
# 4  2012-06-27 01:00:00     3644550        0.0  3019.61106      3648.99048
#
#    Fountain   Microwave        Fridge  Entertainment  Kettle
# 0  7578.729  4752.71713    4109.27931     6909.44380     0.0
# 1  7570.169  4767.66360    4143.27627     6856.28780     0.0
# 2  7625.809  4769.79881   28627.50803     6860.54028     0.0
# 3  7619.389  4816.77343  107712.70900     6896.68636     0.0
# 4  7619.389  4825.31427   76826.05290     6847.78290     0.0

# %%
house5_by_15mins[['date', 'occupancy', 'Tablet', 'Coffee machine',
       'Fountain', 'Microwave', 'Fridge', 'Entertainment', 'Kettle']].iplot(kind = "scatter", x = 'date')
# Out:
# The draw time for this plot will be slow for all clients.
# /Users/glance/anaconda3/lib/python3.6/site-packages/plotly/api/v1/clientresp.py:40: UserWarning:
#
# Estimated Draw Time Too Long
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~liyikang/82.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ### House 6:

# %%
house6.head()
# Out:
#    Unnamed: 0                 date  Lamp   Laptop   Router  Coffee machine  \
# 0           0  2012-06-27 00:00:00   0.0  4.35384  19.3387             0.0
# 1           1  2012-06-27 00:00:01   0.0  4.35384  19.3387             0.0
# 2           2  2012-06-27 00:00:02   0.0  6.47995  19.3387             0.0
# 3           3  2012-06-27 00:00:03   0.0  6.47995  19.3387             0.0
# 4           4  2012-06-27 00:00:04   0.0  4.35384  19.3387             0.0
#
#    Entertainment   Fridge  Kettle
# 0        15.0043  2.19884     0.0
# 1        15.0043  2.19884     0.0
# 2        15.0043  0.00000     0.0
# 3        15.0043  0.00000     0.0
# 4        15.0043  0.00000     0.0

# %% [markdown]
# #### Statistical Characteristics:

# %%
house6.describe()
# Out:
#          Unnamed: 0          Lamp        Laptop        Router  Coffee machine  \
# count  1.883520e+07  1.425600e+07  1.589760e+07  7.603200e+06    1.537920e+07
# mean   9.417600e+06 -8.376633e-02  6.586103e+00  1.917793e+01    3.643533e+00
# std    5.437254e+06  2.567623e+00  6.320948e+00  3.825831e+00    4.375191e+01
# min    0.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00   -1.000000e+00
# 25%    4.708800e+06 -1.000000e+00  4.353840e+00  1.933870e+01    0.000000e+00
# 50%    9.417600e+06  0.000000e+00  6.479950e+00  1.933870e+01    0.000000e+00
# 75%    1.412640e+07  0.000000e+00  6.479950e+00  1.933870e+01    0.000000e+00
# max    1.883520e+07  4.729930e+01  9.364450e+01  2.786790e+01    1.285580e+03
#
#        Entertainment        Fridge        Kettle
# count   1.555200e+07  1.537920e+07  1.270080e+07
# mean    2.341736e+01  1.011450e+01  2.354713e+00
# std     2.186640e+01  3.181019e+01  7.143318e+01
# min    -1.000000e+00 -1.000000e+00 -1.000000e+00
# 25%     1.500430e+01  0.000000e+00  0.000000e+00
# 50%     1.500430e+01  0.000000e+00  0.000000e+00
# 75%     2.139790e+01  2.198840e+00  0.000000e+00
# max     1.535160e+02  1.128580e+03  2.122290e+03

# %%
house6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18835200 entries, 0 to 18835199
# Data columns (total 9 columns):
# Unnamed: 0        int64
# date              object
# Lamp              float64
# Laptop            float64
# Router            float64
# Coffee machine    float64
# Entertainment     float64
# Fridge            float64
# Kettle            float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 1.3+ GB

# %% [markdown]
# #### Correlation:

# %%
pd.DataFrame.corr(house6)
# Out:
#                 Unnamed: 0      Lamp    Laptop    Router  Coffee machine  \
# Unnamed: 0        1.000000  0.072416 -0.033790 -0.055584        0.002007
# Lamp              0.072416  1.000000  0.022549  0.076244        0.018302
# Laptop           -0.033790  0.022549  1.000000  0.193302        0.027232
# Router           -0.055584  0.076244  0.193302  1.000000        0.018071
# Coffee machine    0.002007  0.018302  0.027232  0.018071        1.000000
# Entertainment     0.023260  0.089889  0.136001  0.205047       -0.014171
# Fridge           -0.028748  0.010271  0.021443  0.070357        0.000028
# Kettle           -0.002645  0.020491  0.007476  0.008394        0.009734
#
#                 Entertainment    Fridge    Kettle
# Unnamed: 0           0.023260 -0.028748 -0.002645
# Lamp                 0.089889  0.010271  0.020491
# Laptop               0.136001  0.021443  0.007476
# Router               0.205047  0.070357  0.008394
# Coffee machine      -0.014171  0.000028  0.009734
# Entertainment        1.000000  0.020155  0.028553
# Fridge               0.020155  1.000000  0.001574
# Kettle               0.028553  0.001574  1.000000

# %% [markdown]
# #### Visualize time series data:

# %%
house6_dt = house6[['date', 'Lamp', 'Laptop', 'Router', 'Coffee machine',
       'Entertainment', 'Fridge', 'Kettle']].iloc[:10000, :]
house6_dt.iplot(kind = "scatter", x = 'date')
# Out:
# The draw time for this plot will be slow for all clients.
# /Users/glance/anaconda3/lib/python3.6/site-packages/plotly/api/v1/clientresp.py:40: UserWarning:
#
# Estimated Draw Time Too Long
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~liyikang/84.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# #### minute and 15 minute data:

# %%
group_mins = house6.groupby(np.arange(len(house6))//60)
house6_by_mins = pd.concat((group_mins['date'].first(), group_mins[[c for c in house6.columns if c != 'date']].sum()), axis=1)
house6_by_mins.head()
# Out:
#                   date  Unnamed: 0  Lamp     Laptop     Router  \
# 0  2012-06-27 00:00:00        1770   0.0  325.01370  1190.1742
# 1  2012-06-27 00:01:00        5370   0.0  331.39203  1202.9680
# 2  2012-06-27 00:02:00        8970   0.0  329.26592  1207.2326
# 3  2012-06-27 00:03:00       12570   0.0  322.88759  1200.8357
# 4  2012-06-27 00:04:00       16170   0.0  339.89647  1205.1003
#
#    Coffee machine  Entertainment    Fridge  Kettle
# 0             0.0       891.7332  24.18724     0.0
# 1             0.0      1017.4737  19.78956     0.0
# 2             0.0      1104.8532  24.18724     0.0
# 3             0.0       889.6020  21.98840     0.0
# 4             0.0       891.7332  13.19304     0.0

# %%
house6_by_mins[['date', 'Lamp', 'Laptop', 'Router', 'Coffee machine',
       'Entertainment', 'Fridge', 'Kettle']].iloc[0: 10000, :].iplot(kind = "scatter", x = 'date')
# Out:
# The draw time for this plot will be slow for all clients.
# /Users/glance/anaconda3/lib/python3.6/site-packages/plotly/api/v1/clientresp.py:40: UserWarning:
#
# Estimated Draw Time Too Long
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~liyikang/86.embed" height="525px" width="100%"></iframe>

# %%
group_15mins = house6.groupby(np.arange(len(house6))//900)
house6_by_15mins = pd.concat((group_15mins['date'].first(), group_15mins[[c for c in house6.columns if c != 'date']].sum()), axis=1)
house6_by_15mins.head()
# Out:
#                   date  Unnamed: 0  Lamp      Laptop      Router  \
# 0  2012-06-27 00:00:00      404550   0.0  4962.37601  18040.2554
# 1  2012-06-27 00:15:00     1214550   0.0  4943.24102  18080.7691
# 2  2012-06-27 00:30:00     2024550   0.0  4924.10603  18061.5784
# 3  2012-06-27 00:45:00     2834550   0.0  4953.87157  18076.5045
# 4  2012-06-27 01:00:00     3644550   0.0  4921.97992  18114.8859
#
#    Coffee machine  Entertainment       Fridge  Kettle
# 0             0.0     13714.8585    294.64456     0.0
# 1             0.0     13437.8028  12723.95104     0.0
# 2             0.0     13576.3308   5344.43652     0.0
# 3             0.0     13589.1180   7839.97874     0.0
# 4             0.0     13616.8236  12930.33968     0.0

# %%
house6_by_15mins[['date', 'Lamp', 'Laptop', 'Router', 'Coffee machine',
       'Entertainment', 'Fridge', 'Kettle']].iplot(kind = "scatter", x = 'date')
# Out:
# The draw time for this plot will be slow for all clients.
# /Users/glance/anaconda3/lib/python3.6/site-packages/plotly/api/v1/clientresp.py:40: UserWarning:
#
# Estimated Draw Time Too Long
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~liyikang/88.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# As a Data Scientist, I want to understand the time series algorithms and realize the differences between time series forecasting and traditional regression models.
#
# To Do:
# Choose one feature from any house. Preferably the whole team should choose the same feature so as to have the same sample data to compare accuracy metrics.
# AR models
# MA Models
# ARIMA models
# Holt Winters exponential smoothing model

# %%
#import statsmodels as sm
#sm.tsa.ar_model.AR(np.asarray(house1), missing='drop')
#AR(house1['Kettle'], house1['date'])

# %%
#sm.tsa.arima_model.ARMA(house1, missing='drop', freq='D')

# %%
#sm.tsa.holtwinters.Holt(house1)
